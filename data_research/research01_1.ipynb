# %% [markdown]
# ### Spotify API
#
# - 環境変数を ../_info/.env　(1個上の階層)
# - https://developer.spotify.com/console/
# - https://api.spotify.com/v1
#     - METHOD	ENDPOINT	USAGE
#     - GET	/v1/artists/{id}/albums	Get Artist's Albums
#     - GET	/v1/artists/{id}/related-artists	Get Artist's Related Artists
#     - GET	/v1/artists/{id}/top-tracks	Get Artist's Top Tracks
#     - GET	/v1/artists/{id}	Get Artist
#     - GET	/v1/artists	Get Several Artists

# %%
# Spotify
import requests
import dotenv
dotenv.load_dotenv("../_info/.env")
import os

CLIENT_ID = os.environ["CLIENT_ID"]
CLIENT_SECRET = os.environ["CLIENT_SECRET"]
artist_id = "6U3ybJ9UHNKEdsH7ktGBZ7"

def auth(CLIENT_ID:str,CLIENT_SECRET:str)->str:
    TOKEN_URL = 'https://accounts.spotify.com/api/token'
    '''Get user authorization and set access token.'''
    # Request authorization from user
    payload = {
        'Content-Type': 'application/x-www-form-urlencoded',
        'grant_type': 'client_credentials',
    }
    # `auth=(CLIENT_ID, SECRET)` basically wraps an 'Authorization'
    # header with value:
    # b'Basic ' + b64encode((CLIENT_ID + ':' + SECRET).encode())
    res = requests.post(TOKEN_URL, auth=(CLIENT_ID, CLIENT_SECRET), data=payload)
    res_data = res.json()

    access_token = res_data.get('access_token')
    return access_token

def get_related_artist_info(access_token:str)->json:
    url = f"https://api.spotify.com/v1/artists/{artist_id}/related-artists"
    headers = {'Authorization':f'Bearer {access_token}','Content-Type': 'application/json','Accept': 'application/json'}
    response = requests.get(url, headers=headers)
    return response.json()

if __name__ == "__main__":
    access_token = auth(CLIENT_ID,CLIENT_SECRET)
    data = get_related_artist_info(access_token)
    display(data)
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5MbNzCW3qokGyoo9giHA3V'},
#    'followers': {'href': None, 'total': 680194},
#    'genres': ['atl hip hop',
#     'hip hop',
#     'psychedelic hip hop',
#     'rap',
#     'underground hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/5MbNzCW3qokGyoo9giHA3V',
#    'id': '5MbNzCW3qokGyoo9giHA3V',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb4a703b05c4ae3fafeaec6be6',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051744a703b05c4ae3fafeaec6be6',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1784a703b05c4ae3fafeaec6be6',
#      'width': 160}],
#    'name': 'EARTHGANG',
#    'popularity': 73,
#    'type': 'artist',
#    'uri': 'spotify:artist:5MbNzCW3qokGyoo9giHA3V'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7izarc0fRIPbdZ8cVyChRf'},
#    'followers': {'href': None, 'total': 181493},
#    'genres': ['hip hop', 'rap', 'underground hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/7izarc0fRIPbdZ8cVyChRf',
#    'id': '7izarc0fRIPbdZ8cVyChRf',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebed4c9a5c5a90808cd01acce9',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174ed4c9a5c5a90808cd01acce9',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178ed4c9a5c5a90808cd01acce9',
#      'width': 160}],
#    'name': 'Spillage Village',
#    'popularity': 57,
#    'type': 'artist',
#    'uri': 'spotify:artist:7izarc0fRIPbdZ8cVyChRf'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpXnnKHIhCOUbOLOJGe6o'},
#    'followers': {'href': None, 'total': 155113},
#    'genres': ['hip hop', 'rap', 'southern hip hop', 'underground hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/6XpXnnKHIhCOUbOLOJGe6o',
#    'id': '6XpXnnKHIhCOUbOLOJGe6o',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb8f4c64678465ee55a216d7e6',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051748f4c64678465ee55a216d7e6',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1788f4c64678465ee55a216d7e6',
#      'width': 160}],
#    'name': 'REASON',
#    'popularity': 59,
#    'type': 'artist',
#    'uri': 'spotify:artist:6XpXnnKHIhCOUbOLOJGe6o'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/70gP6Ry4Uo0Yx6uzPIdaiJ'},
#    'followers': {'href': None, 'total': 434596},
#    'genres': ['hip hop',
#     'queens hip hop',
#     'rap',
#     'sudanese pop',
#     'underground hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/70gP6Ry4Uo0Yx6uzPIdaiJ',
#    'id': '70gP6Ry4Uo0Yx6uzPIdaiJ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebe33ef339180da12882d8db11',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174e33ef339180da12882d8db11',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178e33ef339180da12882d8db11',
#      'width': 160}],
#    'name': 'Bas',
#    'popularity': 72,
#    'type': 'artist',
#    'uri': 'spotify:artist:70gP6Ry4Uo0Yx6uzPIdaiJ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Nd1g8fezKoJ6DGauWbZIm'},
#    'followers': {'href': None, 'total': 103647},
#    'genres': ['rap', 'underground hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/1Nd1g8fezKoJ6DGauWbZIm',
#    'id': '1Nd1g8fezKoJ6DGauWbZIm',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb7c7228c1cefc9ed5b1b427ef',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051747c7228c1cefc9ed5b1b427ef',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1787c7228c1cefc9ed5b1b427ef',
#      'width': 160}],
#    'name': 'Beast Coast',
#    'popularity': 53,
#    'type': 'artist',
#    'uri': 'spotify:artist:1Nd1g8fezKoJ6DGauWbZIm'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6aiFCgyKNwF9Rv5TOxnE8E'},
#    'followers': {'href': None, 'total': 332189},
#    'genres': ['dmv rap', 'hip hop', 'rap', 'trap', 'underground hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/6aiFCgyKNwF9Rv5TOxnE8E',
#    'id': '6aiFCgyKNwF9Rv5TOxnE8E',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebd114182665089a11ed26d05c',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174d114182665089a11ed26d05c',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178d114182665089a11ed26d05c',
#      'width': 160}],
#    'name': 'IDK',
#    'popularity': 65,
#    'type': 'artist',
#    'uri': 'spotify:artist:6aiFCgyKNwF9Rv5TOxnE8E'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0NcPKaSNIHAM2RfioH9vMT'},
#    'followers': {'href': None, 'total': 99852},
#    'genres': ['cali rap',
#     'oakland hip hop',
#     'pop rap',
#     'scam rap',
#     'trap soul',
#     'underground hip hop',
#     'vapor trap'],
#    'href': 'https://api.spotify.com/v1/artists/0NcPKaSNIHAM2RfioH9vMT',
#    'id': '0NcPKaSNIHAM2RfioH9vMT',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebfb7530205de2bb3d1ff57d90',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174fb7530205de2bb3d1ff57d90',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178fb7530205de2bb3d1ff57d90',
#      'width': 160}],
#    'name': 'Guapdad 4000',
#    'popularity': 63,
#    'type': 'artist',
#    'uri': 'spotify:artist:0NcPKaSNIHAM2RfioH9vMT'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/75WcpJKWXBV3o3cfluWapK'},
#    'followers': {'href': None, 'total': 151039},
#    'genres': ['hip hop',
#     'indie hip hop',
#     'north carolina hip hop',
#     'underground hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/75WcpJKWXBV3o3cfluWapK',
#    'id': '75WcpJKWXBV3o3cfluWapK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb93963e4c558799e9bb7787d0',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517493963e4c558799e9bb7787d0',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17893963e4c558799e9bb7787d0',
#      'width': 160}],
#    'name': 'Lute',
#    'popularity': 63,
#    'type': 'artist',
#    'uri': 'spotify:artist:75WcpJKWXBV3o3cfluWapK'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5oFkj1qSlyBUmV5d6Edgtq'},
#    'followers': {'href': None, 'total': 163171},
#    'genres': ['hip hop', 'underground hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/5oFkj1qSlyBUmV5d6Edgtq',
#    'id': '5oFkj1qSlyBUmV5d6Edgtq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb7510dccce9a4abf8c49f8ea2',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051747510dccce9a4abf8c49f8ea2',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1787510dccce9a4abf8c49f8ea2',
#      'width': 160}],
#    'name': 'Cozz',
#    'popularity': 59,
#    'type': 'artist',
#    'uri': 'spotify:artist:5oFkj1qSlyBUmV5d6Edgtq'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5REHfa3YDopGOzrxwTsPvH'},
#    'followers': {'href': None, 'total': 72921},
#    'genres': ['alternative r&b', 'atl hip hop', 'underground hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/5REHfa3YDopGOzrxwTsPvH',
#    'id': '5REHfa3YDopGOzrxwTsPvH',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb827a16edc815b62eabe86f03',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174827a16edc815b62eabe86f03',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178827a16edc815b62eabe86f03',
#      'width': 160}],
#    'name': "Deante' Hitchcock",
#    'popularity': 53,
#    'type': 'artist',
#    'uri': 'spotify:artist:5REHfa3YDopGOzrxwTsPvH'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6PDLwWvgYNMfBRLqC1h5cJ'},
#    'followers': {'href': None, 'total': 198383},
#    'genres': ['alternative r&b', 'cali rap', 'underground hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/6PDLwWvgYNMfBRLqC1h5cJ',
#    'id': '6PDLwWvgYNMfBRLqC1h5cJ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb6236dd274273e079379c65bd',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051746236dd274273e079379c65bd',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1786236dd274273e079379c65bd',
#      'width': 160}],
#    'name': 'Buddy',
#    'popularity': 66,
#    'type': 'artist',
#    'uri': 'spotify:artist:6PDLwWvgYNMfBRLqC1h5cJ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Hjbimq43OgxaBRpFXic4x'},
#    'followers': {'href': None, 'total': 575985},
#    'genres': ['alternative r&b',
#     'chicago rap',
#     'hip hop',
#     'rap',
#     'underground hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/7Hjbimq43OgxaBRpFXic4x',
#    'id': '7Hjbimq43OgxaBRpFXic4x',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb87c1e4c80ffe56c4e4b07dc4',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517487c1e4c80ffe56c4e4b07dc4',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17887c1e4c80ffe56c4e4b07dc4',
#      'width': 160}],
#    'name': 'Saba',
#    'popularity': 71,
#    'type': 'artist',
#    'uri': 'spotify:artist:7Hjbimq43OgxaBRpFXic4x'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/68kEuyFKyqrdQQLLsmiatm'},
#    'followers': {'href': None, 'total': 1535191},
#    'genres': ['conscious hip hop',
#     'escape room',
#     'hip hop',
#     'rap',
#     'underground hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/68kEuyFKyqrdQQLLsmiatm',
#    'id': '68kEuyFKyqrdQQLLsmiatm',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb53054f8bc7e0153daefe12cc',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517453054f8bc7e0153daefe12cc',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17853054f8bc7e0153daefe12cc',
#      'width': 160}],
#    'name': 'Vince Staples',
#    'popularity': 73,
#    'type': 'artist',
#    'uri': 'spotify:artist:68kEuyFKyqrdQQLLsmiatm'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5usbqiU7sjvszjWecANDL6'},
#    'followers': {'href': None, 'total': 226180},
#    'genres': ['underground hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/5usbqiU7sjvszjWecANDL6',
#    'id': '5usbqiU7sjvszjWecANDL6',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb0c82d2306defc6cff5a507bc',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051740c82d2306defc6cff5a507bc',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1780c82d2306defc6cff5a507bc',
#      'width': 160}],
#    'name': 'WESTSIDE BOOGIE',
#    'popularity': 60,
#    'type': 'artist',
#    'uri': 'spotify:artist:5usbqiU7sjvszjWecANDL6'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6aaMZ3fcfLv4tEbmY7bjRM'},
#    'followers': {'href': None, 'total': 1105915},
#    'genres': ['hip hop', 'rap', 'tennessee hip hop', 'underground hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/6aaMZ3fcfLv4tEbmY7bjRM',
#    'id': '6aaMZ3fcfLv4tEbmY7bjRM',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb1ff1685224034e6c12538722',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051741ff1685224034e6c12538722',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1781ff1685224034e6c12538722',
#      'width': 160}],
#    'name': 'Isaiah Rashad',
#    'popularity': 73,
#    'type': 'artist',
#    'uri': 'spotify:artist:6aaMZ3fcfLv4tEbmY7bjRM'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1iNqsUDUraNWrj00bqssQG'},
#    'followers': {'href': None, 'total': 399289},
#    'genres': ['hip hop', 'rap', 'underground hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/1iNqsUDUraNWrj00bqssQG',
#    'id': '1iNqsUDUraNWrj00bqssQG',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb080d11275f15655a11b2610d',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174080d11275f15655a11b2610d',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178080d11275f15655a11b2610d',
#      'width': 160}],
#    'name': 'Dreamville',
#    'popularity': 70,
#    'type': 'artist',
#    'uri': 'spotify:artist:1iNqsUDUraNWrj00bqssQG'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6fxyWrfmjcbj5d12gXeiNV'},
#    'followers': {'href': None, 'total': 1791808},
#    'genres': ['dark trap',
#     'drill',
#     'hip hop',
#     'miami hip hop',
#     'rap',
#     'underground hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/6fxyWrfmjcbj5d12gXeiNV',
#    'id': '6fxyWrfmjcbj5d12gXeiNV',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebdd630d7b6b717fb0c56f4554',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174dd630d7b6b717fb0c56f4554',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178dd630d7b6b717fb0c56f4554',
#      'width': 160}],
#    'name': 'Denzel Curry',
#    'popularity': 77,
#    'type': 'artist',
#    'uri': 'spotify:artist:6fxyWrfmjcbj5d12gXeiNV'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0g9vAlRPK9Gt3FKCekk4TW'},
#    'followers': {'href': None, 'total': 894310},
#    'genres': ['alternative hip hop',
#     'conscious hip hop',
#     'escape room',
#     'hip hop',
#     'rap',
#     'southern hip hop',
#     'underground hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/0g9vAlRPK9Gt3FKCekk4TW',
#    'id': '0g9vAlRPK9Gt3FKCekk4TW',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb8910f0a4d6f84c1994adb75c',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051748910f0a4d6f84c1994adb75c',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1788910f0a4d6f84c1994adb75c',
#      'width': 160}],
#    'name': 'Ab-Soul',
#    'popularity': 62,
#    'type': 'artist',
#    'uri': 'spotify:artist:0g9vAlRPK9Gt3FKCekk4TW'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ybINI1qPiFbwDXamRtwxD'},
#    'followers': {'href': None, 'total': 622512},
#    'genres': ['alternative r&b', 'hip hop', 'rap', 'underground hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/1ybINI1qPiFbwDXamRtwxD',
#    'id': '1ybINI1qPiFbwDXamRtwxD',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb2679721181b9708afd42013a',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051742679721181b9708afd42013a',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1782679721181b9708afd42013a',
#      'width': 160}],
#    'name': 'Smino',
#    'popularity': 73,
#    'type': 'artist',
#    'uri': 'spotify:artist:1ybINI1qPiFbwDXamRtwxD'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4mwdnO2jZrMmMVrjcHsZBv'},
#    'followers': {'href': None, 'total': 75932},
#    'genres': ['atl hip hop', 'indie hip hop', 'underground hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/4mwdnO2jZrMmMVrjcHsZBv',
#    'id': '4mwdnO2jZrMmMVrjcHsZBv',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebab765bccb80b5eb0795f8ca9',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174ab765bccb80b5eb0795f8ca9',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178ab765bccb80b5eb0795f8ca9',
#      'width': 160}],
#    'name': 'Kenny Mason',
#    'popularity': 55,
#    'type': 'artist',
#    'uri': 'spotify:artist:4mwdnO2jZrMmMVrjcHsZBv'}]}

# %%
# 歴代人気アーティスト
import requests
from bs4 import BeautifulSoup
url = "https://www.uta-net.com/ranking/index.php"

response = requests.get(url)
soup = BeautifulSoup(response.content)
tbody_list = soup.find("tbody",id="ranking-table-body")
tr_list = tbody_list.find_all("td",class_="sp-none fw-bold")

artist_list = []
for name in tr_list:
    artist_list.append(name.text)

print(set(artist_list))
# Out:
# {'King Gnu', '菅田将暉', 'LiSA', 'RADWIMPS', 'flumpool', 'シェネル', 'HY', '西野カナ', 'back number', 'Mr.Children', '福山雅治', 'GReeeeN', '瑛人', 'DISH//', 'JY', '三代目 J SOUL BROTHERS from EXILE TRIBE', '優里', 'Official髭男dism', 'ONE OK ROCK', 'YOASOBI', 'コブクロ', 'Foorin', 'miwa', 'SEKAI NO OWARI', '米津玄師', '[Alexandros]', 'あいみょん', 'MONGOL800', 'WANIMA', 'Ado', 'ソナーポケット', 'スキマスイッチ'}
